# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
STEM = ['Psychology', 'Biology', 'Math and Statistics',
        'Physical Sciences', 'Computer Science', 'Engineering']
LIBERAL_ARTS = ['Foreign Languages', 'English', 'Communications and Journalism',
               'Art and Performance', 'Social Sciences and History']
OTHER = ['Health Professions', 'Public Administration',
         'Education', 'Agriculture', 'Business', 'Architecture']

# %%
df = pd.read_csv('./percent-bachelors-degrees-women-usa.csv')
df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
fig = plt.figure(figsize=(16, 16))

# STEM degrees
for i, col in enumerate(STEM):
    ax = fig.add_subplot(6, 3, i*3 + 1)
    ax.plot(df['Year'], df[col], c='blue')
    ax.plot(df['Year'], 100 - df[col], c='orange')
    ax.set_ylim(0, 100)
    ax.set_yticks([0, 100])
    ax.set_title(col)
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    # Add text annotation     
    if i == 0:
        ax.text(2005, 85, 'Women')
        ax.text(2007, 10, 'Men')
    elif i == len(STEM) - 1:
        ax.text(2007, 70, 'Men')
        ax.text(2005, 25, 'Women')
    
    # Remove redundancies
    for spine in ax.spines.values():
        spine.set_visible(False)
        
    ax.tick_params(left=False, bottom=False)
    
    if i != len(STEM) - 1:
        ax.set_xticklabels('')
        
# LIBERAL_ARTS degrees
for i, col in enumerate(LIBERAL_ARTS):
    ax = fig.add_subplot(6, 3, i*3 + 2)
    ax.plot(df['Year'], df[col], c='blue')
    ax.plot(df['Year'], 100 - df[col], c='orange')
    ax.set_ylim(0, 100)
    ax.set_yticks([0, 100])
    ax.set_title(col)
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    # Add text annotation     
    if i == 0:
        ax.text(2005, 75, 'Women')
        ax.text(2007, 20, 'Men')
    elif i == len(LIBERAL_ARTS) - 1:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 35, 'Women')
    
    # Remove redundancies
    for spine in ax.spines.values():
        spine.set_visible(False)
        
    ax.tick_params(left=False, bottom=False)
    
    if i != len(LIBERAL_ARTS) - 1:
        ax.set_xticklabels('')
        
# OTHER degrees
for i, col in enumerate(OTHER):
    ax = fig.add_subplot(6, 3, i*3 + 3)
    ax.plot(df['Year'], df[col], c='blue')
    ax.plot(df['Year'], 100 - df[col], c='orange')
    ax.set_ylim(0, 100)
    ax.set_yticks([0, 100])
    ax.set_title(col)
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    # Add text annotation     
    if i == 0:
        ax.text(2005, 95, 'Women')
        ax.text(2007, 5, 'Men')
    elif i == len(OTHER) - 1:
        ax.text(2007, 70, 'Men')
        ax.text(2005, 25, 'Women')
    
    # Remove redundancies
    for spine in ax.spines.values():
        spine.set_visible(False)
        
    ax.tick_params(left=False, bottom=False)
    
    if i != len(OTHER) - 1:
        ax.set_xticklabels('')
    
plt.show()

# %%
fig.savefig('gender_degrees.png')
