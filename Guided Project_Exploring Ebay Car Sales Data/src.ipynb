# %% [markdown]
# # Data Cleaning Project
# ## Exploring Ebay Used Car Sales Data

# %% [markdown]
# ### Explore dataset

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# - Some columns contain many null values
# - The data types are either object or int64

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# - 'name' column seems to need cleaning because it has too much information without structure. It may need to be cut into multiple columns

# %% [markdown]
# ### Clean column names

# %%
import re

# %%
def convert(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

# %%
col_names = autos.columns.values
col_names
# Out:
# array(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'], dtype=object)

# %%
new_col_names = []
for col in col_names:
    if col == 'yearOfRegistration':
        col = 'registration_year'
    elif col == 'monthOfRegistration':
        col = 'registration_month'
    elif col == 'notRepairedDamage':
        col = 'unrepaired_damage'
    elif col == 'dateCreated':
        col = 'ad_created'
    else:
        col = convert(col)
    new_col_names.append(col)
    
new_col_names
# Out:
# ['date_crawled',
#  'name',
#  'seller',
#  'offer_type',
#  'price',
#  'abtest',
#  'vehicle_type',
#  'registration_year',
#  'gearbox',
#  'power_ps',
#  'model',
#  'odometer',
#  'registration_month',
#  'fuel_type',
#  'brand',
#  'unrepaired_damage',
#  'ad_created',
#  'nr_of_pictures',
#  'postal_code',
#  'last_seen']

# %%
autos.columns = new_col_names
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# - Converted all column names from camelcase to snakecase
# - Changed some column names

# %% [markdown]
# ### Clean data types and representation

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-21 16:37:21  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# - columns 'abtest', 'gearbox', and 'unrepaired_damage' have only two unique values. Should determine if they must be converted to boolean type
# - For 'seller' and 'offer_type', almost all values are the same thus they are not very informative
# - 'price' and 'odometer' should be converted to numeric types

# %%
autos[['price', 'odometer']].head()
# Out:
#     price   odometer
# 0  $5,000  150,000km
# 1  $8,500  150,000km
# 2  $8,990   70,000km
# 3  $4,350   70,000km
# 4  $1,350  150,000km

# %%
price = autos['price']
odometer = autos['odometer']

# %%
price = price.str.replace('$', "").str.replace(',', '').astype('int')
odometer = odometer.str.replace('km', '').str.replace(',', '').astype('int')

# %%
autos['price'] = price
autos['odometer'] = odometer
autos.rename(index=str, columns={'odometer': 'odometer_km'}, inplace=True)
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offer_type            50000 non-null object
# price                 50000 non-null int32
# abtest                50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int32
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# ad_created            50000 non-null object
# nr_of_pictures        50000 non-null int64
# postal_code           50000 non-null int64
# ...

# %% [markdown]
# ### Explore numeric data

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['price'].sort_values(ascending=False)
# Out:
# 39705    99999999
# 42221    27322222
# 39377    12345678
# 47598    12345678
# 27371    12345678
# 2897     11111111
# 24384    11111111
# 11137    10000000
# 47634     3890000
# 7814      1300000
# 22947     1234566
# 43049      999999
# 514        999999
# 37585      999990
# 36818      350000
# 14715      345000
# 34723      299000
# 35923      295000
# 12682      265000
# 47337      259000
# 38299      250000
# 37840      220000
# 40918      198000
# 43668      197000
# 28090      194000
# 20351      190000
# 17140      180000
# 11433      175000
# 32840      169999
# 18509      169000
#            ...
# 21171           0
# 24900           0
# 1220            0
# 31264           0
# 24871           0
# 2470            0
# 21256           0
# 29503           0
# 37021           0
# 21253           0
# 47861           0
# 29482           0
# 31336           0
# 35819           0
# 27020           0
# 4266            0
# 2481            0
# 15208           0
# 33620           0
# ...

# %% [markdown]
# - Some values in 'price' are either too high or too low. Needs removal

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# - Seems like 'odometer' is range

# %% [markdown]
# ### Remove Outliers

# %%
from scipy import stats

# %%
pd.Series(np.abs(stats.zscore(autos['price']))).sort_values(ascending=False)
# Out:
# 39705    207.836725
# 42221     56.770747
# 39377     25.640925
# 27371     25.640925
# 47598     25.640925
# 24384     23.074789
# 2897      23.074789
# 11137     20.765265
# 47634      8.065191
# 7814       2.681690
# 22947      2.545681
# 43049      2.058116
# 514        2.058116
# 37585      2.058098
# 36818      0.707047
# 14715      0.696654
# 34723      0.601040
# 35923      0.592725
# 12682      0.530368
# 47337      0.517897
# 38299      0.499190
# 37840      0.436833
# 40918      0.391104
# 43668      0.389025
# 28090      0.382790
# 20351      0.374475
# 17140      0.353690
# 11433      0.343297
# 32840      0.332902
# 18509      0.330825
#             ...
# 25910      0.000083
# 40570      0.000083
# 5513       0.000083
# 8970       0.000083
# 22048      0.000083
# 38640      0.000062
# 38232      0.000062
# 19737      0.000021
# 40630      0.000021
# 42579      0.000021
# 22577      0.000021
# 31465      0.000021
# 38402      0.000021
# 45357      0.000021
# ...

# %%
autos = autos.loc[np.abs(stats.zscore(autos['price'])) < 3]

# %% [markdown]
# - Removed values with z-scores higher than or equal to 3 from 'price' column

# %% [markdown]
# ### Inspect Date Values

# %%
date_cols = ['date_crawled', 'ad_created', 'last_seen', 'registration_year', 'registration_year']
autos[date_cols].head()
# Out:
#           date_crawled           ad_created            last_seen  \
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50
#
#    registration_year  registration_year
# 0               2004               2004
# 1               1997               1997
# 2               2009               2009
# 3               2007               2007
# 4               2003               2003

# %%
autos[date_cols].info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49991 entries, 0 to 49999
# Data columns (total 5 columns):
# date_crawled         49991 non-null object
# ad_created           49991 non-null object
# last_seen            49991 non-null object
# registration_year    49991 non-null int64
# registration_year    49991 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 2.3+ MB

# %%
autos['date_crawled'].str[:10].value_counts(dropna=False, normalize=True).sort_index()
# Out:
# 2016-03-05    0.025385
# 2016-03-06    0.013943
# 2016-03-07    0.035966
# 2016-03-08    0.033266
# 2016-03-09    0.033206
# 2016-03-10    0.032126
# 2016-03-11    0.032486
# 2016-03-12    0.036767
# 2016-03-13    0.015563
# 2016-03-14    0.036627
# 2016-03-15    0.033986
# 2016-03-16    0.029505
# 2016-03-17    0.031526
# 2016-03-18    0.013062
# 2016-03-19    0.034906
# 2016-03-20    0.037827
# 2016-03-21    0.037507
# 2016-03-22    0.032926
# 2016-03-23    0.032386
# 2016-03-24    0.029105
# 2016-03-25    0.031746
# 2016-03-26    0.032486
# 2016-03-27    0.031046
# 2016-03-28    0.034846
# 2016-03-29    0.034166
# 2016-03-30    0.033626
# 2016-03-31    0.031906
# 2016-04-01    0.033806
# 2016-04-02    0.035406
# 2016-04-03    0.038687
# 2016-04-04    0.036507
# 2016-04-05    0.013102
# 2016-04-06    0.003181
# 2016-04-07    0.001420
# Name: date_crawled, dtype: float64

# %% [markdown]
# - The data is crawled from Mar 5 to Apr 7

# %%
autos['ad_created'].str[:10].value_counts(dropna=False, normalize=True).sort_index()
# Out:
# 2015-06-11    0.000020
# 2015-08-10    0.000020
# 2015-09-09    0.000020
# 2015-11-10    0.000020
# 2015-12-05    0.000020
# 2015-12-30    0.000020
# 2016-01-03    0.000020
# 2016-01-07    0.000020
# 2016-01-10    0.000040
# 2016-01-13    0.000020
# 2016-01-14    0.000020
# 2016-01-16    0.000020
# 2016-01-22    0.000020
# 2016-01-27    0.000060
# 2016-01-29    0.000020
# 2016-02-01    0.000020
# 2016-02-02    0.000040
# 2016-02-05    0.000040
# 2016-02-07    0.000020
# 2016-02-08    0.000020
# 2016-02-09    0.000040
# 2016-02-11    0.000020
# 2016-02-12    0.000060
# 2016-02-14    0.000040
# 2016-02-16    0.000020
# 2016-02-17    0.000020
# 2016-02-18    0.000040
# 2016-02-19    0.000060
# 2016-02-20    0.000040
# 2016-02-21    0.000060
#                 ...
# 2016-03-09    0.033226
# 2016-03-10    0.031866
# 2016-03-11    0.032786
# 2016-03-12    0.036607
# 2016-03-13    0.016923
# 2016-03-14    0.035226
# 2016-03-15    0.033746
# 2016-03-16    0.030005
# 2016-03-17    0.031206
# ...

# %%
autos['last_seen'].str[:10].value_counts(dropna=False, normalize=True).sort_index()
# Out:
# 2016-03-05    0.001080
# 2016-03-06    0.004421
# 2016-03-07    0.005361
# 2016-03-08    0.007581
# 2016-03-09    0.009842
# 2016-03-10    0.010762
# 2016-03-11    0.012522
# 2016-03-12    0.023804
# 2016-03-13    0.008982
# 2016-03-14    0.012802
# 2016-03-15    0.015883
# 2016-03-16    0.016443
# 2016-03-17    0.027925
# 2016-03-18    0.007421
# 2016-03-19    0.015743
# 2016-03-20    0.020704
# 2016-03-21    0.020724
# 2016-03-22    0.021584
# 2016-03-23    0.018583
# 2016-03-24    0.019564
# 2016-03-25    0.019203
# 2016-03-26    0.016963
# 2016-03-27    0.016023
# 2016-03-28    0.020864
# 2016-03-29    0.022344
# 2016-03-30    0.024844
# 2016-03-31    0.023824
# 2016-04-01    0.023104
# 2016-04-02    0.024904
# 2016-04-03    0.025365
# 2016-04-04    0.024624
# 2016-04-05    0.124282
# 2016-04-06    0.220980
# 2016-04-07    0.130944
# Name: last_seen, dtype: float64

# %%
autos['registration_year'].sort_values()
# Out:
# 22316    1000
# 49283    1001
# 24511    1111
# 35238    1500
# 32585    1800
# 10556    1800
# 28693    1910
# 3679     1910
# 42181    1910
# 22659    1910
# 30781    1910
# 33295    1910
# 15898    1910
# 46213    1910
# 45157    1910
# 21416    1927
# 22101    1929
# 11246    1931
# 2221     1934
# 2573     1934
# 26607    1937
# 21421    1937
# 39725    1937
# 23804    1937
# 26103    1938
# 24855    1939
# 25792    1941
# 13963    1941
# 11585    1943
# 11047    1948
#          ...
# 14264    2018
# 44548    2018
# 34888    2018
# 34800    2018
# 6927     2018
# 39915    2018
# 46809    2018
# 3716     2018
# 35021    2018
# 38342    2019
# 49185    2019
# 5763     2019
# 27578    2800
# 4549     4100
# 453      4500
# 42079    4800
# 49153    5000
# 4164     5000
# 24519    5000
# 22799    5000
# 27618    5911
# 8360     6200
# 25003    8888
# 13559    9000
# 49910    9000
# 6308     9996
# 33950    9999
# 38076    9999
# 8012     9999
# 14341    9999
# ...

# %% [markdown]
# - 'registration_year' contains many exotic values

# %%
registered_bw_1900_2016 = (autos['registration_year'] > 1900) & (autos['registration_year'] <= 2016)
autos['registration_year'].loc[registered_bw_1900_2016].sort_values().shape
# Out:
# (48021,)

# %%
autos = autos.loc[registered_bw_1900_2016]

# %%
autos['registration_year'].value_counts(normalize=True).sort_index()
# Out:
# 1910    0.000187
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000042
# 1937    0.000083
# 1938    0.000021
# 1939    0.000021
# 1941    0.000042
# 1943    0.000021
# 1948    0.000021
# 1950    0.000062
# 1951    0.000042
# 1952    0.000021
# 1953    0.000021
# 1954    0.000042
# 1955    0.000042
# 1956    0.000104
# 1957    0.000042
# 1958    0.000083
# 1959    0.000146
# 1960    0.000687
# 1961    0.000125
# 1962    0.000083
# 1963    0.000187
# 1964    0.000250
# 1965    0.000354
# 1966    0.000458
# 1967    0.000562
# 1968    0.000541
#           ...
# 1987    0.001562
# 1988    0.002957
# 1989    0.003769
# 1990    0.008226
# 1991    0.007413
# 1992    0.008142
# 1993    0.009267
# 1994    0.013744
# 1995    0.027321
# 1996    0.030070
# 1997    0.042232
# 1998    0.051082
# 1999    0.062452
# 2000    0.069844
# 2001    0.056267
# 2002    0.052748
# 2003    0.056788
# 2004    0.056996
# 2005    0.062785
# 2006    0.056371
# 2007    0.047979
# ...

# %% [markdown]
# - Removed extotic values from 'registration_year"

# %%
autos['registration_month'].value_counts().sort_index()
# Out:
# 0     4586
# 1     3163
# 2     2915
# 3     4897
# 4     3954
# 5     3949
# 6     4211
# 7     3811
# 8     3085
# 9     3300
# 10    3554
# 11    3271
# 12    3325
# Name: registration_month, dtype: int64

# %% [markdown]
# - What does '0' represent in 'registration_month' column?

# %% [markdown]
# ### Aggregate by Brand

# %%
autos['brand'].value_counts()
# Out:
# volkswagen        10187
# bmw                5284
# opel               5194
# mercedes_benz      4579
# audi               4149
# ford               3351
# renault            2274
# peugeot            1418
# fiat               1242
# seat                873
# skoda               770
# mazda               727
# nissan              725
# smart               668
# citroen             668
# toyota              599
# sonstige_autos      524
# hyundai             473
# volvo               444
# mini                415
# mitsubishi          391
# honda               377
# kia                 341
# alfa_romeo          318
# porsche             293
# suzuki              284
# chevrolet           274
# chrysler            176
# daihatsu            123
# dacia               123
# jeep                108
# subaru              105
# land_rover           98
# saab                 77
# jaguar               76
# trabant              75
# daewoo               72
# rover                65
# ...

# %%
top_20_brands = autos['brand'].value_counts().index[:20]

# %%
mean_price_by_brand = {}

for brand in top_20_brands:
    mean_price = autos.loc[autos['brand'] == brand]['price'].mean()
    mean_price_by_brand[brand] = mean_price

# %%
mean_price_by_brand
# Out:
# {'volkswagen': 5426.382546382644,
#  'bmw': 8334.645155185466,
#  'opel': 2876.716403542549,
#  'mercedes_benz': 8485.239571958942,
#  'audi': 9093.65003615329,
#  'ford': 3949.42345568487,
#  'renault': 2395.4164467897976,
#  'peugeot': 3039.4682651622,
#  'fiat': 2711.8011272141707,
#  'seat': 4296.492554410081,
#  'skoda': 6334.91948051948,
#  'mazda': 4010.7716643741405,
#  'nissan': 4664.891034482758,
#  'smart': 3542.706586826347,
#  'citroen': 3699.935628742515,
#  'toyota': 5115.33388981636,
#  'sonstige_autos': 13265.374045801527,
#  'hyundai': 5308.53911205074,
#  'volvo': 4757.108108108108,
#  'mini': 10460.012048192772}

# %%
mean_price_series = pd.Series(mean_price_by_brand)

# %%
agg_by_brand = pd.DataFrame(mean_price_series, columns=['mean_price'])
agg_by_brand
# Out:
#                   mean_price
# volkswagen       5426.382546
# bmw              8334.645155
# opel             2876.716404
# mercedes_benz    8485.239572
# audi             9093.650036
# ford             3949.423456
# renault          2395.416447
# peugeot          3039.468265
# fiat             2711.801127
# seat             4296.492554
# skoda            6334.919481
# mazda            4010.771664
# nissan           4664.891034
# smart            3542.706587
# citroen          3699.935629
# toyota           5115.333890
# sonstige_autos  13265.374046
# hyundai          5308.539112
# volvo            4757.108108
# mini            10460.012048

# %%
mean_mileage_by_brand = {}

for brand in top_20_brands:
    mean_mileage = autos.loc[autos['brand'] == brand]['odometer_km'].mean()
    mean_mileage_by_brand[brand] = mean_mileage

# %%
mean_mileage_series = pd.Series(mean_mileage_by_brand)

# %%
agg_by_brand['mean_mileage'] = mean_mileage_series

# %%
agg_by_brand
# Out:
#                   mean_price   mean_mileage
# volkswagen       5426.382546  128728.281143
# bmw              8334.645155  132434.708554
# opel             2876.716404  129223.142087
# mercedes_benz    8485.239572  130856.082114
# audi             9093.650036  129287.780188
# ford             3949.423456  124068.934646
# renault          2395.416447  128183.817062
# peugeot          3039.468265  127136.812412
# fiat             2711.801127  116553.945250
# seat             4296.492554  121563.573883
# skoda            6334.919481  110954.545455
# mazda            4010.771664  124745.529574
# nissan           4664.891034  118572.413793
# smart            3542.706587   99595.808383
# citroen          3699.935629  119580.838323
# toyota           5115.333890  115709.515860
# sonstige_autos  13265.374046   87395.038168
# hyundai          5308.539112  106511.627907
# volvo            4757.108108  138355.855856
# mini            10460.012048   88602.409639
